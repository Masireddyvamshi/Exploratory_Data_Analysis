# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # LinePlot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [5, 6, 7, 8]
plt.figure(facecolor='lightblue')
plt.plot(
    x, y,
    color='red',          # must be lowercase
    linestyle='--',
    linewidth=3,          # should be int/float, not string
    marker='s',           # use lowercase 'o'
    markersize=5,         # should be int/float
    markerfacecolor='blue',
    markeredgecolor='black',
    label='Example',
    alpha=0.8           # must be between 0 and 1
)
plt.grid()
plt.legend()
plt.show()

# %%
months=[1,2,3,4,5]
product_A=[20,30,40,50,60]
product_B=[100,200,300,400,500] 
plt.plot(months,product_A,label='Product A',color='Black',marker='x')
plt.plot(months,product_B,label='Product B',color='Orange',marker='x')
plt.xticks(months)
plt.yticks([i for i in range(100,1100,100)])
plt.legend()
plt.show()

# %%
# Both products show an upward trend over months
# product b consistently records higher saler than product a
# product a shows slow but steady growthh
# product b shows rapid and strong growth
# No flutuations or declines are observed in the sales of both products

# %%
x=[1,2,3,4,5]
A=[10,50,10,50,10]
B=[10,20,30,40,50]
plt.plot(x,A,label='Product A',color='red',marker='*')
plt.plot(x,B,label='Product B',color='blue',marker='*')
plt.legend()
plt.show()

# %%
# The product b sales are consistent and steady growth
# The product a sales are increasing rapidly and decreasing rapidly over the period of time
# There is fluctuations in product a there is no consitency growth in sales compared to b

# %%
x = [1, 2, 3, 4, 5]
A = [100, 90, 80, 70, 60]
B = [50, 70, 90, 110, 130]

plt.plot(x, A, label="Product A")
plt.plot(x, B, label="Product B") 
plt.legend()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
A = [1, 2, 3, 4, 5]
B = [100, 200, 300, 400, 500]

plt.plot(x, A, label="Product A")
plt.plot(x, B, label="Product B")
plt.legend()
plt.show()

# %%
# Both products show proportional linear growth
# The growth pattern is same, but magnitude is different
# Product B has higher volume, not necessarily a higher growth rate

# %%
prices=[1000,4000,6000,9000]
plt.plot(prices,marker='^',markersize=10,color='Orange',label='Prices')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Histogram

# %%
data = [45, 50, 55, 60, 62, 65, 70, 75, 80]

plt.hist(
    data,
    bins=5,
    color='skyblue',
    edgecolor='black',
    alpha=0.8
)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram Example') 
plt.show()

# %%
df=pd.read_csv(r"C:\Users\masir\Downloads\Datasets\Online Sales Data.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
plt.hist(
    df['Units Sold'],
    bins=5,
    range=(1, 10),
    density=False,
    color='Red',
    edgecolor='green',
    linewidth=4,
    alpha=1,
    label='Units_sold',
    histtype='bar',
    orientation='vertical'
)

plt.legend()
plt.grid()
plt.show()

# %%
# Most of the Units Sold values are concentrated between 1 and 3.
# Units sold less than 2 are close to 100, indicating high frequency at low values.
# The distribution is right-skewed (positively skewed), with a long tail towards higher values.
# Very few observations occur above 6, showing possible outliers or rare high sales.

# %%
plt.hist(
    df['Units Sold'],
    bins=10,
    range=(1, 10),
    density=True,
    color='Red',
    edgecolor='green',
    linewidth=4,
    alpha=1,
    label='Units_sold',
    histtype='step',
    orientation='vertical'
)

plt.legend()
plt.grid()
plt.show()

# %%
plt.hist(
    df['Units Sold'],
    bins=10,
    range=(1, 10),
    density=False,
    color='Red',
    edgecolor='green',
    linewidth=4,
    alpha=1,
    label='Units_sold',
    histtype='stepfilled',
    orientation='vertical'
)

plt.legend()
plt.grid()
plt.show()

# %%
plt.hist(
    df['Units Sold'],
    bins=10,
    range=(1, 10),
    density=True,
    color='Red',
    edgecolor='green',
    linewidth=4,
    alpha=1,
    label='Units_sold',
    histtype='stepfilled',
    orientation='horizontal'
)

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Boxplot

# %%
units_sold = [1,2,2,3,3,4,5,6,10]
plt.boxplot(
    units_sold,
    patch_artist=True,
    showfliers=True
)
plt.title('Units Sold Box Plot')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.boxplot(df['Unit Price'],vert=False,widths=0.5,patch_artist=True,showmeans=True,showfliers=True,label='Outliers')
plt.legend()
plt.show()

# %% [markdown]
# # Pie Chart

# %%
df=pd.read_csv(r"C:\Users\masir\Downloads\Datasets\loan_data_set.csv")
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
gender_val=df['Gender'].value_counts()
# 0°   → right
# 90°  → top
# 180° → left
# 270° → bottom

# %%
plt.pie(gender_val,labels=gender_val.index,autopct='%1.1f%%',colors=['skyblue','yellow'],startangle=180,explode=[0,0.1],radius=1)
plt.show()

# %%
plt.pie(gender_val,labels=gender_val.index,autopct='%1.1f%%',colors=['skyblue','yellow'],startangle=90,explode=[0,0.1],radius=1)
plt.show()

# %%
plt.pie(df['Property_Area'].value_counts(),labels=df['Property_Area'].value_counts().index,autopct='%1.1f%%',colors=['skyblue','yellow','gray'],startangle=270,explode=[0,0.3,0.1],radius=1)
plt.axis('equal')
plt.axis('on')
plt.show()

# %% [markdown]
# # Count Plot

# %%
df=pd.read_csv(r"C:\Users\masir\Downloads\Datasets\loan_data_set.csv")
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
count=df['Gender'].value_counts()

# %%
count
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
plt.bar(count.index,count.values,color='red',label='Gender',alpha=0.5)
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# From the data people who has applied to loan were most of them was male compared to female which was closer to 500

# %% [markdown]
# # Bivariate

# %% [markdown]
# # ScatterPlot

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
plt.scatter(df['ApplicantIncome'],df['CoapplicantIncome'],s=50,marker='o',edgecolors='black',label='Data Points')
plt.xlabel('Applicant Income')
plt.ylabel('Coapplicant Income')
plt.title('ApplicantIncome vs CoapplicantIncome')
plt.show()

# %%
# As we can see there is no relationship between applicant income and coapplicantIncome

# %%
hours = [1,2,3,4,5]
scores = [40,50,60,70,85]

plt.scatter(hours, scores, color='red', s=60)
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Study Hours vs Score')
plt.show()

# %%
# as we can see there is an postive correlation between study hours and Exam Score
# As study hours Increase The Exam score is also getting increased

# %% [markdown]
# # Line Plot

# %%
age = [22, 25, 28, 32, 36, 40, 45]
salary = [25000, 38000, 36000, 55000, 52000, 80000, 78000]  # fluctuations

plt.plot(
    age,
    salary,
    marker='o',
    linestyle='-',
    linewidth=2,
    alpha=0.8,
    label='Salary Trend'
)

plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs Salary with Fluctuations')
plt.legend()
plt.show()

# %%
# 📈 Overall upward trend → career growth

# 🔻 Temporary drops → job switch / gap

# 🔺 Sharp rise → promotion or role change

# %%
df=pd.read_csv(r"C:\Users\masir\Downloads\Datasets\HRDataset_v14.csv")

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
sample=df[[	'EmpID'	,'Sex',	'Department',	'DOB'	,'Salary']]

# %%
sample.shape
# Out:
# (311, 5)

# %%
sample.head()
# Out:
#    EmpID Sex         Department       DOB  Salary
# 0  10026  M   Production         07/10/83   62506
# 1  10084  M               IT/IS  05/05/75  104437
# 2  10196   F  Production         09/19/88   64955
# 3  10088   F  Production         09/27/88   64991
# 4  10069   F  Production         09/08/89   50825

# %%
plt.bar(sample['Sex'],sample['Salary'],color='green',width=0.5,alpha=1)

plt.xlabel('Gender')
plt.ylabel('Salary')
plt.show()

# %%
print(sample[sample['Sex']=='F']['Salary'].sum())
print(sample[sample['Sex']=='F']['Salary'].max())
print(sample[sample['Sex']=='M ']['Salary'].sum())
print(sample[sample['Sex']=='M ']['Salary'].sum())
# Out:
# 11930464
# 250000
# 9534969
# 9534969

# %%
# Female employees are earning highest individual salary compared to male employees
# May be because of high skill or Hard work or may be they are working in the most demanded skills

# %%
plt.bar(sample['Sex'],sample['EmpID'],color='gray',alpha=0.5)
plt.xlabel('Gender')
plt.ylabel('Count Of employyes in each category')
plt.show()

# %%
# The male employees and Femal Employees are approximately equal

# %%
colors = ['#1E88E5', '#90CAF9']
plt.bar(sample['Department'],sample['Salary'],color=colors,alpha=1)
max_salary = sample['Salary'].max()
plt.axhline(y=max_salary, color='red', linestyle='--', linewidth=2)
plt.xticks(rotation=45)
plt.show()

# %%
# The Executive Office Employees are earning highest individual salary compare to Remaining departments
# May be beacuse of higher demand of that Department

# %%
plt.bar(sample['Sex'],sample['Salary'].sum(),color='green',width=0.5,alpha=1)
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.show()

# %%
# The sum of male employees salary was approximately equal to sum of female Employees salary

# %%
IT=sample[sample['Department']=='IT/IS']['Salary']
Sales=sample[sample['Department']=='Sales']['Salary']
Executive_Office=sample[sample['Department']=='Software Engineering']['Salary']

# %%
plt.boxplot([IT, Sales, Executive_Office],
            tick_labels=['IT', 'Sales', 'Executive Office'],
            widths=0.8,
            showmeans=True,
            patch_artist=True)
plt.axhline(y=sample[sample['Department']=='IT/IS']['Salary'].mean(),color='red',linestyle="--")
plt.axhline(y=sample[sample['Department']=='Sales']['Salary'].mean(),color='green',linestyle="--")
plt.axhline(y=sample[sample['Department']=='Software Engineering']['Salary'].mean(),color='green',linestyle="--")
plt.ylabel('Salary')
plt.title('Salary Distribution by Department')
plt.grid
plt.show()

# %%
# Few people are earning more in the It Department Due to high skill or high demand skill
#  Executive office Department  has highest Averge salary comapre to all the Departments

# %%
salary_by_dept=sample.groupby('Department')['Salary'].sum()

# %%
salary_by_dept
# Out:
# Department
# Admin Offices             646127
# Executive Office          250000
# IT/IS                    4853232
# Production              12530291
# Sales                    2140899
# Software Engineering     1044884
# Name: Salary, dtype: int64

# %%
colors = [
    '#1E88E5',  # Blue
    '#43A047',  # Green
    '#FB8C00',  # Orange
    '#E53935',  # Red
    '#8E24AA',  # Purple
    '#00ACC1',  # Cyan
    '#FDD835',  # Yellow
    '#6D4C41',  # Brown
    '#546E7A'   # Grey
]

plt.pie(salary_by_dept.values,labels=salary_by_dept.index,autopct='%1.2f%%',colors=colors)
plt.axis()
plt.show()

# %%
# The data looks clumsy so better to use the bar chart

# %%
plt.bar(salary_by_dept.index,salary_by_dept,color=colors)
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.grid()
plt.show()

# %%
# The Production department receives the highest total salary across all departments.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# # Bubble plot

# %%
df=pd.read_csv(r"C:\Users\masir\Downloads\Datasets\hospital data analysis.csv")

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender      Condition                 Procedure   Cost  \
# 0           1   45  Female  Heart Disease               Angioplasty  15000
# 1           2   60    Male       Diabetes           Insulin Therapy   2000
# 2           3   32  Female  Fractured Arm          X-Ray and Splint    500
# 3           4   75    Male         Stroke    CT Scan and Medication  10000
# 4           5   50  Female         Cancer  Surgery and Chemotherapy  25000
#
#    Length_of_Stay Readmission    Outcome  Satisfaction
# 0               5          No  Recovered             4
# 1               3         Yes     Stable             3
# 2               1          No  Recovered             5
# 3               7         Yes     Stable             2
# 4              10          No  Recovered             4

# %%
sample=df[['Cost','Length_of_Stay','Satisfaction']].sample(n=30)

# %%
gender_map = {'Male': 0, 'Female': 1}
sample['Gender_Code'] = df['Gender'].map(gender_map)

# %%
sample.head()
# Out:
#       Cost  Length_of_Stay  Satisfaction  Gender_Code
# 550  25000              47             4            1
# 945  15000              69             4            1
# 703    100              48             5            0
# 202    800              15             4            1
# 337  12000              25             4            1

# %%
plt.scatter(
    sample['Length_of_Stay'],
    sample['Cost'],
    s=sample['Satisfaction']*50,
    c=sample['Gender_Code'],
    cmap='coolwarm',
    alpha=0.7,
    edgecolors='black'
)
plt.show()
# 🔵 Cool colors (blue) → lower values
# 🔴 Warm colors (red) → higher values
